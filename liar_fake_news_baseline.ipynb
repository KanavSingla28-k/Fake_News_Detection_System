# %% [markdown]
# # Fake News Detection Baseline (LIAR Dataset)
#
# This notebook demonstrates a simple and clean workflow for fake news detection using the LIAR dataset. It includes classical and transformer baselines, with all metrics recorded for reference.

# %% [markdown]
# ## 1. Environment Setup
#
# Install required packages for classical and transformer baselines.

# %%
# Install required packages
# !pip install transformers datasets accelerate adapter-transformers scikit-learn pandas numpy nltk joblib
# Out:
# Requirement already satisfied: transformers in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (4.35.2)
# Requirement already satisfied: datasets in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (2.14.5)
# Requirement already satisfied: accelerate in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (0.21.0)
# Requirement already satisfied: adapter-transformers in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (4.0.0)
# Requirement already satisfied: scikit-learn in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: pandas in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: nltk in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: joblib in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (1.5.2)
# Requirement already satisfied: filelock in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (0.17.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.15.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from datasets) (0.3.7)
# Requirement already satisfied: xxhash in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from datasets) (0.70.15)
# Requirement already satisfied: aiohttp in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from datasets) (3.12.15)
# Requirement already satisfied: psutil in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from accelerate) (7.1.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from accelerate) (2.8.0+cu129)
# Requirement already satisfied: adapters in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from adapter-transformers) (0.1.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: click in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from aiohttp->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from aiohttp->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from aiohttp->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from aiohttp->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets) (3.10)
# Requirement already satisfied: six>=1.5 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from torch>=1.10.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from torch>=1.10.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from torch>=1.10.0->accelerate) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kanaa\onedrive\desktop\projects\fake_news_detection_system\.venv\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.3)

# %% [markdown]
# ## 2. Load and Preprocess LIAR Dataset
#
# Load LIAR dataset and preprocess statements: lowercase, whitespace, URL, stopword removal, lemmatization.

# %%
import pandas as pd
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

columns = [
    "id", "label", "statement", "subject", "speaker", "job_title", "state", "party_affiliation", "barely_true_counts", "false_counts", "half_true_counts", "mostly_true_counts", "pants_on_fire_counts", "context"
]
train_df = pd.read_csv("liar_dataset/train.tsv", sep='\t', names=columns, header=None)
valid_df = pd.read_csv("liar_dataset/valid.tsv", sep='\t', names=columns, header=None)
test_df  = pd.read_csv("liar_dataset/test.tsv",  sep='\t', names=columns, header=None)

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = str(text).lower()
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

train_df['clean_text'] = train_df['statement'].apply(preprocess_text)
valid_df['clean_text'] = valid_df['statement'].apply(preprocess_text)
test_df['clean_text']  = test_df['statement'].apply(preprocess_text)

print("Train shape:", train_df.shape)
print("Valid shape:", valid_df.shape)
print("Test shape:", test_df.shape)
train_df[['label', 'clean_text']].head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kanaa/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\kanaa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Train shape: (10240, 15)
# Valid shape: (1284, 15)
# Test shape: (1267, 15)
#          label                                         clean_text
# 0        false  say annies list political group support third-...
# 1    half-true  decline coal start? started natural gas took s...
# 2  mostly-true  hillary clinton agrees john mccain "by voting ...
# 3        false  health care reform legislation likely mandate ...
# 4    half-true              economic turnaround started end term.

# %% [markdown]
# ## 3. Baseline 1: TF-IDF + Logistic Regression
#
# Train and evaluate a classical baseline using TF-IDF features and Logistic Regression.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import joblib

vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(train_df['clean_text'])
X_valid = vectorizer.transform(valid_df['clean_text'])
X_test = vectorizer.transform(test_df['clean_text'])

y_train = train_df['label']
y_valid = valid_df['label']
y_test = test_df['label']

lr = LogisticRegression(max_iter=500)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
print(classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred, average='weighted'))

# Save model and vectorizer
joblib.dump(lr, "tfidf_lr_model.pkl")
joblib.dump(vectorizer, "tfidf_vectorizer.pkl")
# Out:
#               precision    recall  f1-score   support
#
#  barely-true       0.23      0.18      0.21       212
#        false       0.26      0.31      0.29       249
#    half-true       0.25      0.28      0.26       265
#  mostly-true       0.18      0.20      0.19       241
#   pants-fire       0.17      0.03      0.05        92
#         true       0.24      0.24      0.24       208
#
#     accuracy                           0.23      1267
#    macro avg       0.22      0.21      0.21      1267
# weighted avg       0.23      0.23      0.22      1267
#
# Confusion Matrix:
#  [[39 58 55 34  1 25]
#  [28 77 52 54  5 33]
#  [38 47 75 68  3 34]
#  [32 39 64 49  2 55]
#  [15 29 18 12  3 15]
#  [16 41 42 55  4 50]]
# F1 Score: 0.22472185423428373
# ['tfidf_vectorizer.pkl']

# %% [markdown]
# ## 4. Baseline 2: Hybrid TF-IDF + LightGBM on LIAR

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from lightgbm import LGBMClassifier
from lightgbm import early_stopping, log_evaluation

# 1. Prepare data
X_train = train_df["clean_text"].astype(str)
y_train = train_df["label"]
X_valid = valid_df["clean_text"].astype(str)
y_valid = valid_df["label"]
X_test  = test_df["clean_text"].astype(str)
y_test  = test_df["label"]

# 2. TF-IDF Features (word + bigram)
tfidf = TfidfVectorizer(max_features=10000, ngram_range=(1,2))
X_train_tfidf = tfidf.fit_transform(X_train)
X_valid_tfidf = tfidf.transform(X_valid)
X_test_tfidf  = tfidf.transform(X_test)

# 3. Train LightGBM Classifier
lgbm = LGBMClassifier(
    num_leaves=64,
    n_estimators=1000,
    learning_rate=0.05,
    objective="multiclass",
    random_state=42
)
lgbm.fit(
    X_train_tfidf, y_train,
    eval_set=[(X_valid_tfidf, y_valid)],
    eval_metric="multi_logloss",
    callbacks=[early_stopping(50), log_evaluation(100)]
)

# 4. Validation Results
y_pred_val = lgbm.predict(X_valid_tfidf)
print("\nValidation Results:")
print(classification_report(y_valid, y_pred_val))
print("F1 Score:", f1_score(y_valid, y_pred_val, average='weighted'))
print("Confusion Matrix:\n", confusion_matrix(y_valid, y_pred_val))

# 5. Final Test Results
y_pred_test = lgbm.predict(X_test_tfidf)
print("\nFinal Test Results:")
print(classification_report(y_test, y_pred_test))
print("F1 Score:", f1_score(y_test, y_pred_test, average='weighted'))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_test))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008455 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 29421
# [LightGBM] [Info] Number of data points in the train set: 10240, number of used features: 1217
# [LightGBM] [Info] Start training from score -1.823105
# [LightGBM] [Info] Start training from score -1.635658
# [LightGBM] [Info] Start training from score -1.577720
# [LightGBM] [Info] Start training from score -1.652337
# [LightGBM] [Info] Start training from score -2.501846
# [LightGBM] [Info] Start training from score -1.809892
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [20]	valid_0's multi_logloss: 1.73911
#
# Validation Results:
#               precision    recall  f1-score   support
#
#  barely-true       0.23      0.12      0.16       237
#        false       0.28      0.35      0.31       263
#    half-true       0.21      0.32      0.26       248
#  mostly-true       0.27      0.31      0.29       251
#   pants-fire       0.29      0.07      0.11       116
#         true       0.20      0.17      0.18       169
#
#     accuracy                           0.24      1284
#    macro avg       0.25      0.22      0.22      1284
# weighted avg       0.25      0.24      0.23      1284
#
# F1 Score: 0.23155320808465543
# Confusion Matrix:
#  [[28 63 72 48  7 19]
#  [33 91 74 43  7 15]
#  [26 57 79 61  3 22]
#  [18 39 65 79  2 48]
#  [12 46 34 10  8  6]
#  [ 4 33 47 56  1 28]]
#
# Final Test Results:
#               precision    recall  f1-score   support
#
#  barely-true       0.25      0.14      0.18       212
#        false       0.26      0.34      0.29       249
#    half-true       0.25      0.34      0.29       265
#  mostly-true       0.21      0.26      0.23       241
#   pants-fire       0.09      0.01      0.02        92
#         true       0.24      0.16      0.19       208
#
#     accuracy                           0.24      1267
#    macro avg       0.22      0.21      0.20      1267
# weighted avg       0.23      0.24      0.22      1267
#
# F1 Score: 0.22424908962758408
# Confusion Matrix:
#  [[29 63 65 38  2 15]
#  [19 85 71 48  2 24]
#  [25 54 91 64  3 28]
#  [17 55 73 62  0 34]
#  [16 27 21 19  1  8]
#  [ 9 49 49 64  3 34]]
# c:\Users\kanaa\OneDrive\Desktop\Projects\Fake_News_Detection_System\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\kanaa\OneDrive\Desktop\Projects\Fake_News_Detection_System\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
